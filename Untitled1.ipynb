# %%
import cv2
from matplotlib import pyplot as plt
img = cv2.imread('seaweed/PR_20081011_004248_819_LC16.png')
hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
print hsv[0][0]
plt.imshow(hsv),plt.show()
# Out:
# [100  69 119]
# (<matplotlib.image.AxesImage at 0x11f304ad0>, None)
